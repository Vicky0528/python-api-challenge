# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
from datetime import datetime
import pandas as pd
import numpy as np
import requests
import time
import csv
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
counter = 0
term = 0
result = []
print("Beginning Data Retrieval")
print("-----------------------------")
for i in range(len(cities)):
    query_url = url + "appid=" + api_key + "&q=" + cities[i]
    weather_response = requests.get(query_url)
    if weather_response.ok:
        print(f"Processing Record {counter%50} of Set {(term//50)+1} | {cities[i]}")
        counter = counter + 1
        term = term + 1
        result.append(weather_response.json())
    else:
        print("City not found. Skipping...")
        counter = counter
        term = term
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 1 of Set 1 | hofn
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | laguna
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | hasaki
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | mar del plata
# Processing Record 8 of Set 1 | mahebourg
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | palmer
# Processing Record 12 of Set 1 | yar-sale
# Processing Record 13 of Set 1 | kudahuvadhoo
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | goianesia
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | tsaratanana
# Processing Record 19 of Set 1 | lebu
# Processing Record 20 of Set 1 | ryazhsk
# Processing Record 21 of Set 1 | lima
# Processing Record 22 of Set 1 | moose factory
# Processing Record 23 of Set 1 | springdale
# Processing Record 24 of Set 1 | punta arenas
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 25 of Set 1 | vestmannaeyjar
# Processing Record 26 of Set 1 | pevek
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | atuona
# City not found. Skipping...
# Processing Record 29 of Set 1 | longyearbyen
# Processing Record 30 of Set 1 | talnakh
# Processing Record 31 of Set 1 | provideniya
# Processing Record 32 of Set 1 | walvis bay
# Processing Record 33 of Set 1 | cherskiy
# Processing Record 34 of Set 1 | luau
# Processing Record 35 of Set 1 | oktyabrskiy
# Processing Record 36 of Set 1 | alofi
# Processing Record 37 of Set 1 | brooks
# Processing Record 38 of Set 1 | dingle
# Processing Record 39 of Set 1 | cabo san lucas
# Processing Record 40 of Set 1 | saskylakh
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | sar-e pul
# Processing Record 43 of Set 1 | denia
# Processing Record 44 of Set 1 | teknaf
# Processing Record 45 of Set 1 | faanui
# Processing Record 46 of Set 1 | pistsovo
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 0 of Set 2 | airai
# Processing Record 1 of Set 2 | codrington
# Processing Record 2 of Set 2 | demba
# Processing Record 3 of Set 2 | agutaya
# Processing Record 4 of Set 2 | barrow
# City not found. Skipping...
# Processing Record 5 of Set 2 | arauca
# Processing Record 6 of Set 2 | teya
# Processing Record 7 of Set 2 | severo-kurilsk
# Processing Record 8 of Set 2 | klaksvik
# City not found. Skipping...
# Processing Record 9 of Set 2 | bardsir
# Processing Record 10 of Set 2 | kavieng
# Processing Record 11 of Set 2 | tuy hoa
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | jalu
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | leh
# Processing Record 17 of Set 2 | jhargram
# Processing Record 18 of Set 2 | ponta do sol
# Processing Record 19 of Set 2 | yellowknife
# Processing Record 20 of Set 2 | lavrentiya
# Processing Record 21 of Set 2 | eberndorf
# Processing Record 22 of Set 2 | lilongwe
# Processing Record 23 of Set 2 | morehead
# Processing Record 24 of Set 2 | kholodnyy
# Processing Record 25 of Set 2 | visby
# Processing Record 26 of Set 2 | toora-khem
# City not found. Skipping...
# Processing Record 27 of Set 2 | sorland
# Processing Record 28 of Set 2 | north bend
# Processing Record 29 of Set 2 | new norfolk
# Processing Record 30 of Set 2 | tayu
# Processing Record 31 of Set 2 | okha
# City not found. Skipping...
# Processing Record 32 of Set 2 | posse
# Processing Record 33 of Set 2 | marawi
# Processing Record 34 of Set 2 | iqaluit
# Processing Record 35 of Set 2 | dongsheng
# Processing Record 36 of Set 2 | noumea
# Processing Record 37 of Set 2 | merauke
# Processing Record 38 of Set 2 | tual
# City not found. Skipping...
# Processing Record 39 of Set 2 | mizdah
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | grand gaube
# Processing Record 42 of Set 2 | lokosovo
# Processing Record 43 of Set 2 | agadir
# Processing Record 44 of Set 2 | san cristobal
# Processing Record 45 of Set 2 | sakaiminato
# Processing Record 46 of Set 2 | cape town
# Processing Record 47 of Set 2 | souillac
# City not found. Skipping...
# Processing Record 48 of Set 2 | norman wells
# Processing Record 49 of Set 2 | akhisar
# Processing Record 0 of Set 3 | assiniboia
# Processing Record 1 of Set 3 | marzuq
# Processing Record 2 of Set 3 | axim
# Processing Record 3 of Set 3 | melbu
# Processing Record 4 of Set 3 | madimba
# Processing Record 5 of Set 3 | denpasar
# City not found. Skipping...
# Processing Record 6 of Set 3 | chuy
# Processing Record 7 of Set 3 | east london
# Processing Record 8 of Set 3 | peniche
# Processing Record 9 of Set 3 | benguela
# Processing Record 10 of Set 3 | opuwo
# City not found. Skipping...
# Processing Record 11 of Set 3 | hambantota
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | vaini
# Processing Record 15 of Set 3 | ambon
# Processing Record 16 of Set 3 | kurumkan
# Processing Record 17 of Set 3 | hobart
# Processing Record 18 of Set 3 | kodiak
# Processing Record 19 of Set 3 | bud
# Processing Record 20 of Set 3 | eyl
# Processing Record 21 of Set 3 | kandi
# Processing Record 22 of Set 3 | visnes
# Processing Record 23 of Set 3 | avera
# City not found. Skipping...
# Processing Record 24 of Set 3 | moroni
# Processing Record 25 of Set 3 | sept-iles
# Processing Record 26 of Set 3 | sitka
# Processing Record 27 of Set 3 | huarmey
# Processing Record 28 of Set 3 | cabinda
# Processing Record 29 of Set 3 | fairbanks
# Processing Record 30 of Set 3 | pitimbu
# Processing Record 31 of Set 3 | lagoa
# Processing Record 32 of Set 3 | sobolevo
# Processing Record 33 of Set 3 | vila do maio
# Processing Record 34 of Set 3 | port hedland
# Processing Record 35 of Set 3 | leningradskiy
# Processing Record 36 of Set 3 | tinskoy
# Processing Record 37 of Set 3 | avarua
# Processing Record 38 of Set 3 | saldanha
# Processing Record 39 of Set 3 | thompson
# City not found. Skipping...
# Processing Record 40 of Set 3 | penzance
# Processing Record 41 of Set 3 | tamworth
# Processing Record 42 of Set 3 | saint-prosper
# Processing Record 43 of Set 3 | ribeira grande
# Processing Record 44 of Set 3 | warrington
# Processing Record 45 of Set 3 | taoudenni
# City not found. Skipping...
# Processing Record 46 of Set 3 | lamu
# Processing Record 47 of Set 3 | awbari
# Processing Record 48 of Set 3 | chapais
# Processing Record 49 of Set 3 | general pico
# Processing Record 0 of Set 4 | whitehorse
# Processing Record 1 of Set 4 | luderitz
# Processing Record 2 of Set 4 | strezhevoy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 4 | altamira
# Processing Record 4 of Set 4 | tuktoyaktuk
# Processing Record 5 of Set 4 | lompoc
# Processing Record 6 of Set 4 | the valley
# Processing Record 7 of Set 4 | lakes entrance
# Processing Record 8 of Set 4 | kimbe
# Processing Record 9 of Set 4 | phalaborwa
# Processing Record 10 of Set 4 | kruisfontein
# Processing Record 11 of Set 4 | saint george
# Processing Record 12 of Set 4 | marostica
# Processing Record 13 of Set 4 | vanimo
# City not found. Skipping...
# Processing Record 14 of Set 4 | santiago del estero
# Processing Record 15 of Set 4 | saint-philippe
# Processing Record 16 of Set 4 | dikson
# Processing Record 17 of Set 4 | qaanaaq
# Processing Record 18 of Set 4 | arak
# City not found. Skipping...
# Processing Record 19 of Set 4 | deputatskiy
# Processing Record 20 of Set 4 | ponta delgada
# Processing Record 21 of Set 4 | mindelo
# Processing Record 22 of Set 4 | westport
# Processing Record 23 of Set 4 | afua
# Processing Record 24 of Set 4 | ichhawar
# Processing Record 25 of Set 4 | florianopolis
# Processing Record 26 of Set 4 | villa rica
# Processing Record 27 of Set 4 | qitaihe
# Processing Record 28 of Set 4 | polyarnyye zori
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 4 | tocopilla
# Processing Record 30 of Set 4 | wanning
# Processing Record 31 of Set 4 | beaupre
# Processing Record 32 of Set 4 | roald
# City not found. Skipping...
# Processing Record 33 of Set 4 | misratah
# City not found. Skipping...
# Processing Record 34 of Set 4 | hualmay
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of Set 4 | tommot
# Processing Record 36 of Set 4 | maracacume
# Processing Record 37 of Set 4 | nikolskoye
# Processing Record 38 of Set 4 | artvin
# Processing Record 39 of Set 4 | sorong
# Processing Record 40 of Set 4 | lorengau
# Processing Record 41 of Set 4 | vondrozo
# Processing Record 42 of Set 4 | hobyo
# Processing Record 43 of Set 4 | iracoubo
# Processing Record 44 of Set 4 | port macquarie
# Processing Record 45 of Set 4 | pangnirtung
# Processing Record 46 of Set 4 | tromso
# City not found. Skipping...
# Processing Record 47 of Set 4 | cayenne
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 48 of Set 4 | ahipara
# City not found. Skipping...
# Processing Record 49 of Set 4 | tuatapere
# Processing Record 0 of Set 5 | puerto padre
# Processing Record 1 of Set 5 | mananjary
# Processing Record 2 of Set 5 | tiksi
# Processing Record 3 of Set 5 | athabasca
# Processing Record 4 of Set 5 | zvishavane
# Processing Record 5 of Set 5 | perth
# Processing Record 6 of Set 5 | samarai
# Processing Record 7 of Set 5 | osakarovka
# City not found. Skipping...
# Processing Record 8 of Set 5 | adwa
# Processing Record 9 of Set 5 | bethel
# Processing Record 10 of Set 5 | yumen
# Processing Record 11 of Set 5 | irricana
# Processing Record 12 of Set 5 | marquette
# Processing Record 13 of Set 5 | katsuura
# Processing Record 14 of Set 5 | kizilskoye
# Processing Record 15 of Set 5 | kisangani
# Processing Record 16 of Set 5 | anadyr
# Processing Record 17 of Set 5 | olinda
# Processing Record 18 of Set 5 | bathsheba
# Processing Record 19 of Set 5 | salalah
# Processing Record 20 of Set 5 | port moresby
# Processing Record 21 of Set 5 | darovskoy
# City not found. Skipping...
# Processing Record 22 of Set 5 | aksu
# Processing Record 23 of Set 5 | gimli
# Processing Record 24 of Set 5 | manono
# Processing Record 25 of Set 5 | kalmunai
# Processing Record 26 of Set 5 | iquitos
# Processing Record 27 of Set 5 | ojinaga
# Processing Record 28 of Set 5 | belmonte
# Processing Record 29 of Set 5 | makakilo city
# Processing Record 30 of Set 5 | livingstone
# Processing Record 31 of Set 5 | muriti
# Processing Record 32 of Set 5 | rudnogorsk
# Processing Record 33 of Set 5 | titay
# Processing Record 34 of Set 5 | tura
# Processing Record 35 of Set 5 | wielun
# Processing Record 36 of Set 5 | chokurdakh
# Processing Record 37 of Set 5 | kidal
# Processing Record 38 of Set 5 | mount gambier
# City not found. Skipping...
# Processing Record 39 of Set 5 | ilulissat
# Processing Record 40 of Set 5 | novo oriente
# Processing Record 41 of Set 5 | ostersund
# Processing Record 42 of Set 5 | nishihara
# Processing Record 43 of Set 5 | miri
# Processing Record 44 of Set 5 | brezovica pri ljubljani
# Processing Record 45 of Set 5 | ajdabiya
# Processing Record 46 of Set 5 | emerald
# Processing Record 47 of Set 5 | cap malheureux
# Processing Record 48 of Set 5 | pushkinskiye gory
# Processing Record 49 of Set 5 | carutapera
# Processing Record 0 of Set 6 | sivas
# Processing Record 1 of Set 6 | praia
# Processing Record 2 of Set 6 | comodoro rivadavia
# Processing Record 3 of Set 6 | vao
# Processing Record 4 of Set 6 | loreto
# Processing Record 5 of Set 6 | vardo
# Processing Record 6 of Set 6 | necochea
# Processing Record 7 of Set 6 | arman
# Processing Record 8 of Set 6 | george town
# Processing Record 9 of Set 6 | krasnoarmeysk
# Processing Record 10 of Set 6 | anloga
# Processing Record 11 of Set 6 | nanortalik
# Processing Record 12 of Set 6 | fortuna
# Processing Record 13 of Set 6 | ambovombe
# Processing Record 14 of Set 6 | plouzane
# Processing Record 15 of Set 6 | ketchikan
# Processing Record 16 of Set 6 | dicabisagan
# City not found. Skipping...
# Processing Record 17 of Set 6 | bowen
# Processing Record 18 of Set 6 | harpanahalli
# Processing Record 19 of Set 6 | cockburn town
# Processing Record 20 of Set 6 | baculin
# City not found. Skipping...
# Processing Record 21 of Set 6 | yarada
# Processing Record 22 of Set 6 | chicama
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 23 of Set 6 | quatis
# Processing Record 24 of Set 6 | kavaratti
# Processing Record 25 of Set 6 | beberibe
# Processing Record 26 of Set 6 | sao jose da coroa grande
# Processing Record 27 of Set 6 | sioux lookout
# Processing Record 28 of Set 6 | fasa
# Processing Record 29 of Set 6 | vila franca do campo
# Processing Record 30 of Set 6 | kaitangata
# City not found. Skipping...
# Processing Record 31 of Set 6 | yerbogachen
# Processing Record 32 of Set 6 | torbay
# Processing Record 33 of Set 6 | honiara
# Processing Record 34 of Set 6 | te anau
# Processing Record 35 of Set 6 | buchanan
# Processing Record 36 of Set 6 | springbok
# Processing Record 37 of Set 6 | carquefou
# Processing Record 38 of Set 6 | namatanai
# City not found. Skipping...
# Processing Record 39 of Set 6 | tamiahua
# Processing Record 40 of Set 6 | kieta
# Processing Record 41 of Set 6 | mangai
# Processing Record 42 of Set 6 | bambanglipuro
# City not found. Skipping...
# Processing Record 43 of Set 6 | roebourne
# City not found. Skipping...
# Processing Record 44 of Set 6 | srandakan
# Processing Record 45 of Set 6 | esperance
# Processing Record 46 of Set 6 | cao bang
# Processing Record 47 of Set 6 | lahaina
# Processing Record 48 of Set 6 | inta
# Processing Record 49 of Set 6 | derzhavinsk
# Processing Record 0 of Set 7 | guarda
# Processing Record 1 of Set 7 | saint-louis
# Processing Record 2 of Set 7 | sokode
# Processing Record 3 of Set 7 | linhares
# City not found. Skipping...
# Processing Record 4 of Set 7 | kiama
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 7 | sao joao da barra
# Processing Record 6 of Set 7 | hami
# Processing Record 7 of Set 7 | zhigansk
# Processing Record 8 of Set 7 | nemuro
# Processing Record 9 of Set 7 | amapa
# Processing Record 10 of Set 7 | alta floresta
# City not found. Skipping...
# Processing Record 11 of Set 7 | portland
# Processing Record 12 of Set 7 | kirkwall
# Processing Record 13 of Set 7 | sehithwa
# Processing Record 14 of Set 7 | coahuayana
# Processing Record 15 of Set 7 | martinsville
# Processing Record 16 of Set 7 | carnarvon
# Processing Record 17 of Set 7 | hanzhong
# Processing Record 18 of Set 7 | wingham
# Processing Record 19 of Set 7 | ibung
# City not found. Skipping...
# Processing Record 20 of Set 7 | piacabucu
# Processing Record 21 of Set 7 | gejiu
# Processing Record 22 of Set 7 | paciran
# Processing Record 23 of Set 7 | steinbach
# Processing Record 24 of Set 7 | atar
# Processing Record 25 of Set 7 | havelock
# Processing Record 26 of Set 7 | urucara
# Processing Record 27 of Set 7 | shu
# Processing Record 28 of Set 7 | flinders
# Processing Record 29 of Set 7 | evanston
# Processing Record 30 of Set 7 | skibbereen
# Processing Record 31 of Set 7 | skjervoy
# Processing Record 32 of Set 7 | omura
# Processing Record 33 of Set 7 | half moon bay
# Processing Record 34 of Set 7 | shimoda
# Processing Record 35 of Set 7 | griffith
# Processing Record 36 of Set 7 | san patricio
# Processing Record 37 of Set 7 | aklavik
# Processing Record 38 of Set 7 | aneho
# Processing Record 39 of Set 7 | aykhal
# Processing Record 40 of Set 7 | los llanos de aridane
# Processing Record 41 of Set 7 | muisne
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 7 | kloulklubed
# City not found. Skipping...
# Processing Record 43 of Set 7 | balkanabat
# Processing Record 44 of Set 7 | chapleau
# Processing Record 45 of Set 7 | constitucion
# Processing Record 46 of Set 7 | tokur
# Processing Record 47 of Set 7 | akdepe
# City not found. Skipping...
# Processing Record 48 of Set 7 | broken hill
# Processing Record 49 of Set 7 | ancud
# City not found. Skipping...
# Processing Record 0 of Set 8 | san jose
# Processing Record 1 of Set 8 | isangel
# Processing Record 2 of Set 8 | baishishan
# Processing Record 3 of Set 8 | hoquiam
# Processing Record 4 of Set 8 | uyutne
# City not found. Skipping...
# Processing Record 5 of Set 8 | kaseda
# Processing Record 6 of Set 8 | presidencia roque saenz pena
# Processing Record 7 of Set 8 | biak
# Processing Record 8 of Set 8 | magadan
# Processing Record 9 of Set 8 | namibe
# Processing Record 10 of Set 8 | lowestoft
# Processing Record 11 of Set 8 | hamilton
# Processing Record 12 of Set 8 | rawson
# Processing Record 13 of Set 8 | aquiraz
# Processing Record 14 of Set 8 | buerarema
# Processing Record 15 of Set 8 | shingu
# Processing Record 16 of Set 8 | mangaratiba
# Processing Record 17 of Set 8 | kilindoni
# Processing Record 18 of Set 8 | bocaiuva
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 8 | myitkyina
# Processing Record 20 of Set 8 | bonfim
# Processing Record 21 of Set 8 | poum
# Processing Record 22 of Set 8 | koslan
# Processing Record 23 of Set 8 | xiongyue
# Processing Record 24 of Set 8 | punta de bombon
# Processing Record 25 of Set 8 | hohhot
# Processing Record 26 of Set 8 | karratha
# Processing Record 27 of Set 8 | cidreira
# Processing Record 28 of Set 8 | dabat
# Processing Record 29 of Set 8 | salinas
# Processing Record 30 of Set 8 | muros
# City not found. Skipping...
# Processing Record 31 of Set 8 | cobh
# Processing Record 32 of Set 8 | veere
# City not found. Skipping...
# Processing Record 33 of Set 8 | mitzic
# Processing Record 34 of Set 8 | baza
# Processing Record 35 of Set 8 | jasper
# Processing Record 36 of Set 8 | dunedin
# Processing Record 37 of Set 8 | puerto escondido
# Processing Record 38 of Set 8 | gumdag
# Processing Record 39 of Set 8 | kamenka
# Processing Record 40 of Set 8 | kosh-agach
# Processing Record 41 of Set 8 | bambous virieux
# Processing Record 42 of Set 8 | sao paulo de olivenca
# Processing Record 43 of Set 8 | margate
# Processing Record 44 of Set 8 | amloh
# Processing Record 45 of Set 8 | noyabrsk
# Processing Record 46 of Set 8 | praia da vitoria
# Processing Record 47 of Set 8 | abu zabad
# Processing Record 48 of Set 8 | churapcha
# Processing Record 49 of Set 8 | tasiilaq
# Processing Record 0 of Set 9 | bahir dar
# Processing Record 1 of Set 9 | viedma
# Processing Record 2 of Set 9 | ranong
# Processing Record 3 of Set 9 | tabat
# Processing Record 4 of Set 9 | geraldton
# Processing Record 5 of Set 9 | bereda
# Processing Record 6 of Set 9 | west bay
# Processing Record 7 of Set 9 | diego de almagro
# Processing Record 8 of Set 9 | beira
# Processing Record 9 of Set 9 | muravlenko
# Processing Record 10 of Set 9 | houma
# Processing Record 11 of Set 9 | buala
# Processing Record 12 of Set 9 | moerai
# Processing Record 13 of Set 9 | pisco
# Processing Record 14 of Set 9 | kumluca
# Processing Record 15 of Set 9 | nome
# Processing Record 16 of Set 9 | roccastrada
# Processing Record 17 of Set 9 | vaitape
# Processing Record 18 of Set 9 | san quintin
# Processing Record 19 of Set 9 | ibra
# City not found. Skipping...
# Processing Record 20 of Set 9 | vawkavysk
# Processing Record 21 of Set 9 | velingara
# Processing Record 22 of Set 9 | majene
# Processing Record 23 of Set 9 | vanavara
# Processing Record 24 of Set 9 | port keats
# City not found. Skipping...
# Processing Record 25 of Set 9 | grindavik
# Processing Record 26 of Set 9 | kulhudhuffushi
# Processing Record 27 of Set 9 | pizarro
# Processing Record 28 of Set 9 | narsaq
# Processing Record 29 of Set 9 | nivala
# Processing Record 30 of Set 9 | huacho
# Processing Record 31 of Set 9 | srednekolymsk
# Processing Record 32 of Set 9 | upernavik
# Processing Record 33 of Set 9 | fort-shevchenko
# Processing Record 34 of Set 9 | orlik
# Processing Record 35 of Set 9 | san benito
# City not found. Skipping...
# Processing Record 36 of Set 9 | la ronge
# Processing Record 37 of Set 9 | vernon
# Processing Record 38 of Set 9 | pont-rouge
# Processing Record 39 of Set 9 | brae
# Processing Record 40 of Set 9 | krasnozerskoye
# Processing Record 41 of Set 9 | porto novo
# Processing Record 42 of Set 9 | coihaique
# City not found. Skipping...
# Processing Record 43 of Set 9 | wells
# Processing Record 44 of Set 9 | bilibino
# Processing Record 45 of Set 9 | dejen
# Processing Record 46 of Set 9 | zyryanka
# City not found. Skipping...
# Processing Record 47 of Set 9 | kokoda
# Processing Record 48 of Set 9 | bageshwar
# Processing Record 49 of Set 9 | verin getashen
# Processing Record 0 of Set 10 | bloomington
# Processing Record 1 of Set 10 | aranos
# Processing Record 2 of Set 10 | cabedelo
# Processing Record 3 of Set 10 | acajutla
# Processing Record 4 of Set 10 | pimentel
# Processing Record 5 of Set 10 | parkes
# Processing Record 6 of Set 10 | matagami
# Processing Record 7 of Set 10 | kodinsk
# Processing Record 8 of Set 10 | tiznit
# Processing Record 9 of Set 10 | bilma
# Processing Record 10 of Set 10 | ewa beach
# Processing Record 11 of Set 10 | robertsport
# Processing Record 12 of Set 10 | villa maria
# Processing Record 13 of Set 10 | elliot
# Processing Record 14 of Set 10 | kahului
# Processing Record 15 of Set 10 | aksarka
# Processing Record 16 of Set 10 | hollins
# Processing Record 17 of Set 10 | marystown
# Processing Record 18 of Set 10 | okhotsk
# Processing Record 19 of Set 10 | sur
# Processing Record 20 of Set 10 | cooma
# Processing Record 21 of Set 10 | port blair
# Processing Record 22 of Set 10 | sao filipe
# Processing Record 23 of Set 10 | moundsville
# Processing Record 24 of Set 10 | mana
# Processing Record 25 of Set 10 | villarrica
# Processing Record 26 of Set 10 | bara
# Processing Record 27 of Set 10 | plettenberg bay
# Processing Record 28 of Set 10 | balikpapan
# Processing Record 29 of Set 10 | awjilah
# Processing Record 30 of Set 10 | tilichiki
# Processing Record 31 of Set 10 | emboscada
# Processing Record 32 of Set 10 | oranjemund
# Processing Record 33 of Set 10 | kharabali
# Processing Record 34 of Set 10 | dourbali
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of Set 10 | sinj
# Processing Record 36 of Set 10 | akalkot
# Processing Record 37 of Set 10 | wagar
# City not found. Skipping...
# Processing Record 38 of Set 10 | touros
# Processing Record 39 of Set 10 | ocampo
# Processing Record 40 of Set 10 | boyle
# Processing Record 41 of Set 10 | blackfoot
# City not found. Skipping...
# Processing Record 42 of Set 10 | saint anthony
# Processing Record 43 of Set 10 | salem
# Processing Record 44 of Set 10 | igrim
# Processing Record 45 of Set 10 | namtsy
# Processing Record 46 of Set 10 | raton
# Processing Record 47 of Set 10 | ayan
# Processing Record 48 of Set 10 | qaqortoq
# Processing Record 49 of Set 10 | luwuk
# City not found. Skipping...
# Processing Record 0 of Set 11 | muleba
# Processing Record 1 of Set 11 | altay
# Processing Record 2 of Set 11 | guerrero negro
# Processing Record 3 of Set 11 | wajima
# Processing Record 4 of Set 11 | wisla
# City not found. Skipping...
# Processing Record 5 of Set 11 | senigallia
# Processing Record 6 of Set 11 | clarksburg
# Processing Record 7 of Set 11 | inhambane
# Processing Record 8 of Set 11 | navolato
# Processing Record 9 of Set 11 | abu dhabi
# Processing Record 10 of Set 11 | umm kaddadah
# Processing Record 11 of Set 11 | mayo
# Processing Record 12 of Set 11 | henderson
# Processing Record 13 of Set 11 | aswan
# Processing Record 14 of Set 11 | beroroha
# Processing Record 15 of Set 11 | elko
# Processing Record 16 of Set 11 | pokhara
# Processing Record 17 of Set 11 | araouane
# Processing Record 18 of Set 11 | richards bay
# Processing Record 19 of Set 11 | khandbari
# Processing Record 20 of Set 11 | sebezh
# Processing Record 21 of Set 11 | belyy yar
# Processing Record 22 of Set 11 | balabac
# Processing Record 23 of Set 11 | oskemen
# Processing Record 24 of Set 11 | mogadishu
# Processing Record 25 of Set 11 | port hardy
# Processing Record 26 of Set 11 | juneau
# City not found. Skipping...
# Processing Record 27 of Set 11 | cartagena
# Processing Record 28 of Set 11 | tucurui
# Processing Record 29 of Set 11 | meadow lake
# Processing Record 30 of Set 11 | beringovskiy
# Processing Record 31 of Set 11 | grand baie
# Processing Record 32 of Set 11 | nekhayevskiy
# Processing Record 33 of Set 11 | atasu
# Processing Record 34 of Set 11 | lida
# Processing Record 35 of Set 11 | talcahuano
# Processing Record 36 of Set 11 | ulkan
# Processing Record 37 of Set 11 | malibu
# Processing Record 38 of Set 11 | porto velho
# Processing Record 39 of Set 11 | pringsewu
# Processing Record 40 of Set 11 | milton
# Processing Record 41 of Set 11 | paamiut
# Processing Record 42 of Set 11 | maningrida
# Processing Record 43 of Set 11 | itapetinga
# Processing Record 44 of Set 11 | shetpe
# Processing Record 45 of Set 11 | saint-joseph
# Processing Record 46 of Set 11 | abrau-dyurso
# Processing Record 47 of Set 11 | labuhan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
s1 = json.dumps(result)
d2 = json.loads(s1)
weather_data = open('../files/weather.csv', 'w')

csvwriter = csv.writer(weather_data)
count = 0
for emp in result:
    if count == 0:
        header = emp.keys()
        csvwriter.writerow(header)
        count += 1
    csvwriter.writerow(emp.values())
weather_data.close()

# %%
City = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []
for item in range(len(result)):
    City.append(result[item]['name'])
    Cloudiness.append(result[item]['clouds']['all'])
    Country.append(result[item]['sys']['country'])
    Date.append(result[item]['dt'])
    Humidity.append(result[item]['main']['humidity'])
    Lat.append(result[item]['coord']['lat'])
    Lng.append(result[item]['coord']['lon'])
    Max_Temp.append(result[item]['main']['temp_max'])
    Wind_Speed.append(result[item]['wind']['speed'])
df = pd.DataFrame(list(zip(City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max_Temp, Wind_Speed)), 
               columns =['City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Lat', 'Lng', 'Max_Temp', 'Wind_Speed']) 
df.count()
# Out:
# City          548
# Cloudiness    548
# Country       548
# Date          548
# Humidity      548
# Lat           548
# Lng           548
# Max_Temp      548
# Wind_Speed    548
# dtype: int64

# %%
df.head()
# Out:
#       City  Cloudiness Country        Date  Humidity    Lat     Lng  Max_Temp  \
# 0  Ushuaia          75      AR  1573025207        86 -54.81  -68.31    274.15
# 1     Hofn         100      IS  1573025207        91  64.25  -15.21    273.79
# 2    Kapaa           1      US  1573025208        88  22.08 -159.32    298.15
# 3   Laguna          40      BZ  1573025208        94  16.17  -88.94    296.15
# 4     Hilo           1      US  1573025208        78  19.71 -155.08    298.15
#
#    Wind_Speed
# 0        3.60
# 1        6.70
# 2        2.60
# 3        0.94
# 4        2.10

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#df2 = df.copy()
#df2['Date'] = pd.to_datetime(df['Date'])
#df2.head()
#datetime.fromtimestamp(df['Date']).strftime('%Y-%m-%d')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(x=df['Lat'], y=df['Max_Temp'], alpha=0.8, edgecolors ="black")
plt.grid()
plt.title("City Latitude Vs. Max Temperature (10/20/2019)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.savefig("../Images/LatVsMaxTep.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(x=df['Lat'], y=df['Humidity'], alpha=0.8, edgecolors ="black")
plt.grid()
plt.title("City Latitude Vs. Humidity (10/20/2019)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../Images/LatVsHum.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(x=df['Lat'], y=df['Cloudiness'], alpha=0.8, edgecolors ="black")
plt.grid()
plt.title("City Latitude Vs. Cloudiness (10/20/2019)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%) (%)")
plt.savefig("../Images/LatVsCloud.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(x=df['Lat'], y=df['Wind_Speed'], alpha=0.8, edgecolors ="black")
plt.grid()
plt.title("City Latitude Vs. Wind Speed (10/20/2019)")
plt.xlabel("Latitude")
plt.ylabel("Wind_Speed (mph)")
plt.savefig("../Images/LatVsWind.png")
plt.show()
